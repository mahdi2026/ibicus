# %% [markdown]
# # Bias Correction with ibicus: Complete Tutorial
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR_REPO/blob/main/notebooks/Bias_Correction_with_ibicus_Colab.ipynb)
#
# This notebook demonstrates bias correction using the **ISIMIP method** from ibicus.
#
# **References**:
# - ibicus: [https://github.com/ecmwf-projects/ibicus](https://github.com/ecmwf-projects/ibicus)
# - Docs: [https://ibicus.readthedocs.io/](https://ibicus.readthedocs.io/)
# - Paper: Spuler et al. 2024, GMD, doi:[10.5194/gmd-17-1249-2024](https://doi.org/10.5194/gmd-17-1249-2024)
